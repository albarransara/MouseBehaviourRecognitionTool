# %% [markdown]
# # Frame Classification using ResNet + TCN 512 augmented
#
# - Create the LSTM model
# - Cross validate the model using different hyperparameters configurations
# - Train the best model
# - Evaluate the best model within the testing videos

# %%
from utils2 import *
import os

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend

# %%
import tensorflow
import keras

tensorflow.__version__
# Out:
# '2.15.0'

# %%
keras.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ## Train models
#
# We will use the best configuration we found with our wandb project

# %%
best_config = {
    'abs_path': '../', # project path 
    'sequence_length': 600, 
    'backbone': 'resnet',
    'layers': 'tcn',
    'dropout_rate': 0.5,
    'num_layers': 2,
    'num_units': 512,
    'loss': 'binary_crossentropy',
    'optimizer': 'adam',
    'learning_rate': 0.001,
    'epochs': 50,
    'batch_size': 32,
    'es_monitor': 'val_prc',
    'es_mode': 'max',
    'es_patience': 5,
    'norm' : False,
    'num_heads' : 1,
    'model_name' : 'tcn12_aumented',
    'kernel_size': 3,
}

# %% [markdown]
# ## Final model Training & Evaluation

# %%
metrics = train_test_model(best_config)
# Out:
# (355, 600, 512) (355, 600, 2)
# (61, 600, 512) (61, 600, 2)
# Running experiment for Grooming
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 1.1154 - tp: 15456.0000 - fp: 47631.0000 - tn: 143088.0000 - fn: 6825.0000 - accuracy: 0.7443 - precision: 0.2450 - recall: 0.6937 - prc: 0.2906
# Epoch 1: val_loss improved from inf to 13.29562, saving model to tcn12_aumented_grooming.h5
# /Users/saraalbarran/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12/12 [==============================] - 52s 4s/step - loss: 1.1154 - tp: 15456.0000 - fp: 47631.0000 - tn: 143088.0000 - fn: 6825.0000 - accuracy: 0.7443 - precision: 0.2450 - recall: 0.6937 - prc: 0.2906 - val_loss: 13.2956 - val_tp: 3473.0000 - val_fp: 33080.0000 - val_tn: 46.0000 - val_fn: 1.0000 - val_accuracy: 0.0961 - val_precision: 0.0950 - val_recall: 0.9997 - val_prc: 0.0964
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4965 - tp: 18980.0000 - fp: 31273.0000 - tn: 159446.0000 - fn: 3301.0000 - accuracy: 0.8377 - precision: 0.3777 - recall: 0.8518 - prc: 0.5737
# Epoch 2: val_loss improved from 13.29562 to 5.79570, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.4965 - tp: 18980.0000 - fp: 31273.0000 - tn: 159446.0000 - fn: 3301.0000 - accuracy: 0.8377 - precision: 0.3777 - recall: 0.8518 - prc: 0.5737 - val_loss: 5.7957 - val_tp: 3280.0000 - val_fp: 22453.0000 - val_tn: 10673.0000 - val_fn: 194.0000 - val_accuracy: 0.3812 - val_precision: 0.1275 - val_recall: 0.9442 - val_prc: 0.1612
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6389 - tp: 19422.0000 - fp: 37337.0000 - tn: 153382.0000 - fn: 2859.0000 - accuracy: 0.8113 - precision: 0.3422 - recall: 0.8717 - prc: 0.4976
# Epoch 3: val_loss improved from 5.79570 to 1.42173, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.6389 - tp: 19422.0000 - fp: 37337.0000 - tn: 153382.0000 - fn: 2859.0000 - accuracy: 0.8113 - precision: 0.3422 - recall: 0.8717 - prc: 0.4976 - val_loss: 1.4217 - val_tp: 531.0000 - val_fp: 1153.0000 - val_tn: 31973.0000 - val_fn: 2943.0000 - val_accuracy: 0.8881 - val_precision: 0.3153 - val_recall: 0.1528 - val_prc: 0.1698
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5659 - tp: 17891.0000 - fp: 31602.0000 - tn: 159117.0000 - fn: 4390.0000 - accuracy: 0.8310 - precision: 0.3615 - recall: 0.8030 - prc: 0.5100
# Epoch 4: val_loss did not improve from 1.42173
# 12/12 [==============================] - 35s 3s/step - loss: 0.5659 - tp: 17891.0000 - fp: 31602.0000 - tn: 159117.0000 - fn: 4390.0000 - accuracy: 0.8310 - precision: 0.3615 - recall: 0.8030 - prc: 0.5100 - val_loss: 13.5974 - val_tp: 3474.0000 - val_fp: 33069.0000 - val_tn: 57.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0965 - val_precision: 0.0951 - val_recall: 1.0000 - val_prc: 0.0958
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3393 - tp: 19141.0000 - fp: 26626.0000 - tn: 164093.0000 - fn: 3140.0000 - accuracy: 0.8603 - precision: 0.4182 - recall: 0.8591 - prc: 0.6822
# Epoch 5: val_loss did not improve from 1.42173
# 12/12 [==============================] - 41s 3s/step - loss: 0.3393 - tp: 19141.0000 - fp: 26626.0000 - tn: 164093.0000 - fn: 3140.0000 - accuracy: 0.8603 - precision: 0.4182 - recall: 0.8591 - prc: 0.6822 - val_loss: 1.5325 - val_tp: 141.0000 - val_fp: 1080.0000 - val_tn: 32046.0000 - val_fn: 3333.0000 - val_accuracy: 0.8794 - val_precision: 0.1155 - val_recall: 0.0406 - val_prc: 0.0997
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2682 - tp: 19791.0000 - fp: 17689.0000 - tn: 173030.0000 - fn: 2490.0000 - accuracy: 0.9053 - precision: 0.5280 - recall: 0.8882 - prc: 0.7693
# Epoch 6: val_loss did not improve from 1.42173
# 12/12 [==============================] - 37s 3s/step - loss: 0.2682 - tp: 19791.0000 - fp: 17689.0000 - tn: 173030.0000 - fn: 2490.0000 - accuracy: 0.9053 - precision: 0.5280 - recall: 0.8882 - prc: 0.7693 - val_loss: 9.2524 - val_tp: 3039.0000 - val_fp: 26210.0000 - val_tn: 6916.0000 - val_fn: 435.0000 - val_accuracy: 0.2720 - val_precision: 0.1039 - val_recall: 0.8748 - val_prc: 0.1118
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2415 - tp: 19995.0000 - fp: 14977.0000 - tn: 175742.0000 - fn: 2286.0000 - accuracy: 0.9190 - precision: 0.5717 - recall: 0.8974 - prc: 0.7939
# Epoch 7: val_loss did not improve from 1.42173
# 12/12 [==============================] - 36s 3s/step - loss: 0.2415 - tp: 19995.0000 - fp: 14977.0000 - tn: 175742.0000 - fn: 2286.0000 - accuracy: 0.9190 - precision: 0.5717 - recall: 0.8974 - prc: 0.7939 - val_loss: 5.5137 - val_tp: 3445.0000 - val_fp: 23163.0000 - val_tn: 9963.0000 - val_fn: 29.0000 - val_accuracy: 0.3663 - val_precision: 0.1295 - val_recall: 0.9917 - val_prc: 0.1876
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2382 - tp: 20801.0000 - fp: 20254.0000 - tn: 170465.0000 - fn: 1480.0000 - accuracy: 0.8980 - precision: 0.5067 - recall: 0.9336 - prc: 0.7858
# Epoch 8: val_loss did not improve from 1.42173
# 12/12 [==============================] - 35s 3s/step - loss: 0.2382 - tp: 20801.0000 - fp: 20254.0000 - tn: 170465.0000 - fn: 1480.0000 - accuracy: 0.8980 - precision: 0.5067 - recall: 0.9336 - prc: 0.7858 - val_loss: 6.0254 - val_tp: 3457.0000 - val_fp: 27217.0000 - val_tn: 5909.0000 - val_fn: 17.0000 - val_accuracy: 0.2559 - val_precision: 0.1127 - val_recall: 0.9951 - val_prc: 0.1749
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2347 - tp: 20567.0000 - fp: 19115.0000 - tn: 171604.0000 - fn: 1714.0000 - accuracy: 0.9022 - precision: 0.5183 - recall: 0.9231 - prc: 0.7875
# Epoch 9: val_loss improved from 1.42173 to 1.30346, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.2347 - tp: 20567.0000 - fp: 19115.0000 - tn: 171604.0000 - fn: 1714.0000 - accuracy: 0.9022 - precision: 0.5183 - recall: 0.9231 - prc: 0.7875 - val_loss: 1.3035 - val_tp: 3431.0000 - val_fp: 14892.0000 - val_tn: 18234.0000 - val_fn: 43.0000 - val_accuracy: 0.5919 - val_precision: 0.1873 - val_recall: 0.9876 - val_prc: 0.5596
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2134 - tp: 20309.0000 - fp: 13674.0000 - tn: 177045.0000 - fn: 1972.0000 - accuracy: 0.9265 - precision: 0.5976 - recall: 0.9115 - prc: 0.8130
# Epoch 10: val_loss improved from 1.30346 to 0.57622, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.2134 - tp: 20309.0000 - fp: 13674.0000 - tn: 177045.0000 - fn: 1972.0000 - accuracy: 0.9265 - precision: 0.5976 - recall: 0.9115 - prc: 0.8130 - val_loss: 0.5762 - val_tp: 1722.0000 - val_fp: 6875.0000 - val_tn: 26251.0000 - val_fn: 1752.0000 - val_accuracy: 0.7643 - val_precision: 0.2003 - val_recall: 0.4957 - val_prc: 0.3536
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3118 - tp: 20731.0000 - fp: 30052.0000 - tn: 160667.0000 - fn: 1550.0000 - accuracy: 0.8516 - precision: 0.4082 - recall: 0.9304 - prc: 0.6606
# Epoch 11: val_loss did not improve from 0.57622
# 12/12 [==============================] - 35s 3s/step - loss: 0.3118 - tp: 20731.0000 - fp: 30052.0000 - tn: 160667.0000 - fn: 1550.0000 - accuracy: 0.8516 - precision: 0.4082 - recall: 0.9304 - prc: 0.6606 - val_loss: 0.6358 - val_tp: 3359.0000 - val_fp: 7333.0000 - val_tn: 25793.0000 - val_fn: 115.0000 - val_accuracy: 0.7965 - val_precision: 0.3142 - val_recall: 0.9669 - val_prc: 0.6626
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2415 - tp: 20566.0000 - fp: 20826.0000 - tn: 169893.0000 - fn: 1715.0000 - accuracy: 0.8942 - precision: 0.4969 - recall: 0.9230 - prc: 0.7778
# Epoch 12: val_loss did not improve from 0.57622
# 12/12 [==============================] - 35s 3s/step - loss: 0.2415 - tp: 20566.0000 - fp: 20826.0000 - tn: 169893.0000 - fn: 1715.0000 - accuracy: 0.8942 - precision: 0.4969 - recall: 0.9230 - prc: 0.7778 - val_loss: 1.1096 - val_tp: 3397.0000 - val_fp: 8828.0000 - val_tn: 24298.0000 - val_fn: 77.0000 - val_accuracy: 0.7567 - val_precision: 0.2779 - val_recall: 0.9778 - val_prc: 0.5158
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2161 - tp: 20760.0000 - fp: 17465.0000 - tn: 173254.0000 - fn: 1521.0000 - accuracy: 0.9109 - precision: 0.5431 - recall: 0.9317 - prc: 0.8010
# Epoch 13: val_loss did not improve from 0.57622
# 12/12 [==============================] - 35s 3s/step - loss: 0.2161 - tp: 20760.0000 - fp: 17465.0000 - tn: 173254.0000 - fn: 1521.0000 - accuracy: 0.9109 - precision: 0.5431 - recall: 0.9317 - prc: 0.8010 - val_loss: 1.3596 - val_tp: 3420.0000 - val_fp: 12187.0000 - val_tn: 20939.0000 - val_fn: 54.0000 - val_accuracy: 0.6655 - val_precision: 0.2191 - val_recall: 0.9845 - val_prc: 0.5013
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1822 - tp: 20945.0000 - fp: 13655.0000 - tn: 177064.0000 - fn: 1336.0000 - accuracy: 0.9296 - precision: 0.6053 - recall: 0.9400 - prc: 0.8532
# Epoch 14: val_loss did not improve from 0.57622
# 12/12 [==============================] - 35s 3s/step - loss: 0.1822 - tp: 20945.0000 - fp: 13655.0000 - tn: 177064.0000 - fn: 1336.0000 - accuracy: 0.9296 - precision: 0.6053 - recall: 0.9400 - prc: 0.8532 - val_loss: 0.9676 - val_tp: 3425.0000 - val_fp: 9732.0000 - val_tn: 23394.0000 - val_fn: 49.0000 - val_accuracy: 0.7328 - val_precision: 0.2603 - val_recall: 0.9859 - val_prc: 0.5706
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1741 - tp: 20891.0000 - fp: 12361.0000 - tn: 178358.0000 - fn: 1390.0000 - accuracy: 0.9354 - precision: 0.6283 - recall: 0.9376 - prc: 0.8655
# Epoch 15: val_loss improved from 0.57622 to 0.56947, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1741 - tp: 20891.0000 - fp: 12361.0000 - tn: 178358.0000 - fn: 1390.0000 - accuracy: 0.9354 - precision: 0.6283 - recall: 0.9376 - prc: 0.8655 - val_loss: 0.5695 - val_tp: 3412.0000 - val_fp: 8275.0000 - val_tn: 24851.0000 - val_fn: 62.0000 - val_accuracy: 0.7722 - val_precision: 0.2919 - val_recall: 0.9822 - val_prc: 0.7931
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1651 - tp: 21155.0000 - fp: 13393.0000 - tn: 177326.0000 - fn: 1126.0000 - accuracy: 0.9318 - precision: 0.6123 - recall: 0.9495 - prc: 0.8744
# Epoch 16: val_loss did not improve from 0.56947
# 12/12 [==============================] - 35s 3s/step - loss: 0.1651 - tp: 21155.0000 - fp: 13393.0000 - tn: 177326.0000 - fn: 1126.0000 - accuracy: 0.9318 - precision: 0.6123 - recall: 0.9495 - prc: 0.8744 - val_loss: 0.6695 - val_tp: 3423.0000 - val_fp: 10742.0000 - val_tn: 22384.0000 - val_fn: 51.0000 - val_accuracy: 0.7051 - val_precision: 0.2417 - val_recall: 0.9853 - val_prc: 0.8101
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1752 - tp: 21204.0000 - fp: 15026.0000 - tn: 175693.0000 - fn: 1077.0000 - accuracy: 0.9244 - precision: 0.5853 - recall: 0.9517 - prc: 0.8362
# Epoch 17: val_loss did not improve from 0.56947
# 12/12 [==============================] - 35s 3s/step - loss: 0.1752 - tp: 21204.0000 - fp: 15026.0000 - tn: 175693.0000 - fn: 1077.0000 - accuracy: 0.9244 - precision: 0.5853 - recall: 0.9517 - prc: 0.8362 - val_loss: 0.5982 - val_tp: 3424.0000 - val_fp: 9389.0000 - val_tn: 23737.0000 - val_fn: 50.0000 - val_accuracy: 0.7421 - val_precision: 0.2672 - val_recall: 0.9856 - val_prc: 0.8105
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1526 - tp: 20964.0000 - fp: 10220.0000 - tn: 180499.0000 - fn: 1317.0000 - accuracy: 0.9458 - precision: 0.6723 - recall: 0.9409 - prc: 0.8903
# Epoch 18: val_loss improved from 0.56947 to 0.47296, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1526 - tp: 20964.0000 - fp: 10220.0000 - tn: 180499.0000 - fn: 1317.0000 - accuracy: 0.9458 - precision: 0.6723 - recall: 0.9409 - prc: 0.8903 - val_loss: 0.4730 - val_tp: 3393.0000 - val_fp: 6759.0000 - val_tn: 26367.0000 - val_fn: 81.0000 - val_accuracy: 0.8131 - val_precision: 0.3342 - val_recall: 0.9767 - val_prc: 0.8287
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2290 - tp: 20985.0000 - fp: 16377.0000 - tn: 174342.0000 - fn: 1296.0000 - accuracy: 0.9170 - precision: 0.5617 - recall: 0.9418 - prc: 0.7836
# Epoch 19: val_loss did not improve from 0.47296
# 12/12 [==============================] - 35s 3s/step - loss: 0.2290 - tp: 20985.0000 - fp: 16377.0000 - tn: 174342.0000 - fn: 1296.0000 - accuracy: 0.9170 - precision: 0.5617 - recall: 0.9418 - prc: 0.7836 - val_loss: 1.4990 - val_tp: 3450.0000 - val_fp: 16939.0000 - val_tn: 16187.0000 - val_fn: 24.0000 - val_accuracy: 0.5365 - val_precision: 0.1692 - val_recall: 0.9931 - val_prc: 0.5506
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2075 - tp: 20481.0000 - fp: 14490.0000 - tn: 176229.0000 - fn: 1800.0000 - accuracy: 0.9235 - precision: 0.5857 - recall: 0.9192 - prc: 0.8165
# Epoch 20: val_loss did not improve from 0.47296
# 12/12 [==============================] - 35s 3s/step - loss: 0.2075 - tp: 20481.0000 - fp: 14490.0000 - tn: 176229.0000 - fn: 1800.0000 - accuracy: 0.9235 - precision: 0.5857 - recall: 0.9192 - prc: 0.8165 - val_loss: 0.4790 - val_tp: 1215.0000 - val_fp: 1837.0000 - val_tn: 31289.0000 - val_fn: 2259.0000 - val_accuracy: 0.8881 - val_precision: 0.3981 - val_recall: 0.3497 - val_prc: 0.3403
# Epoch 21/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2319 - tp: 21338.0000 - fp: 23621.0000 - tn: 167098.0000 - fn: 943.0000 - accuracy: 0.8847 - precision: 0.4746 - recall: 0.9577 - prc: 0.8151
# Epoch 21: val_loss did not improve from 0.47296
# 12/12 [==============================] - 35s 3s/step - loss: 0.2319 - tp: 21338.0000 - fp: 23621.0000 - tn: 167098.0000 - fn: 943.0000 - accuracy: 0.8847 - precision: 0.4746 - recall: 0.9577 - prc: 0.8151 - val_loss: 0.8238 - val_tp: 697.0000 - val_fp: 3081.0000 - val_tn: 30045.0000 - val_fn: 2777.0000 - val_accuracy: 0.8399 - val_precision: 0.1845 - val_recall: 0.2006 - val_prc: 0.1490
# Epoch 22/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1969 - tp: 20692.0000 - fp: 14076.0000 - tn: 176643.0000 - fn: 1589.0000 - accuracy: 0.9265 - precision: 0.5951 - recall: 0.9287 - prc: 0.8261
# Epoch 22: val_loss improved from 0.47296 to 0.31267, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1969 - tp: 20692.0000 - fp: 14076.0000 - tn: 176643.0000 - fn: 1589.0000 - accuracy: 0.9265 - precision: 0.5951 - recall: 0.9287 - prc: 0.8261 - val_loss: 0.3127 - val_tp: 581.0000 - val_fp: 473.0000 - val_tn: 32653.0000 - val_fn: 2893.0000 - val_accuracy: 0.9080 - val_precision: 0.5512 - val_recall: 0.1672 - val_prc: 0.4531
# Epoch 23/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1800 - tp: 21168.0000 - fp: 15621.0000 - tn: 175098.0000 - fn: 1113.0000 - accuracy: 0.9214 - precision: 0.5754 - recall: 0.9500 - prc: 0.8419
# Epoch 23: val_loss did not improve from 0.31267
# 12/12 [==============================] - 35s 3s/step - loss: 0.1800 - tp: 21168.0000 - fp: 15621.0000 - tn: 175098.0000 - fn: 1113.0000 - accuracy: 0.9214 - precision: 0.5754 - recall: 0.9500 - prc: 0.8419 - val_loss: 0.6428 - val_tp: 1934.0000 - val_fp: 8632.0000 - val_tn: 24494.0000 - val_fn: 1540.0000 - val_accuracy: 0.7221 - val_precision: 0.1830 - val_recall: 0.5567 - val_prc: 0.2725
# Epoch 24/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1554 - tp: 21350.0000 - fp: 13538.0000 - tn: 177181.0000 - fn: 931.0000 - accuracy: 0.9321 - precision: 0.6120 - recall: 0.9582 - prc: 0.8914
# Epoch 24: val_loss did not improve from 0.31267
# 12/12 [==============================] - 35s 3s/step - loss: 0.1554 - tp: 21350.0000 - fp: 13538.0000 - tn: 177181.0000 - fn: 931.0000 - accuracy: 0.9321 - precision: 0.6120 - recall: 0.9582 - prc: 0.8914 - val_loss: 0.3427 - val_tp: 2195.0000 - val_fp: 4131.0000 - val_tn: 28995.0000 - val_fn: 1279.0000 - val_accuracy: 0.8522 - val_precision: 0.3470 - val_recall: 0.6318 - val_prc: 0.4797
# Epoch 25/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1429 - tp: 21438.0000 - fp: 13081.0000 - tn: 177638.0000 - fn: 843.0000 - accuracy: 0.9346 - precision: 0.6210 - recall: 0.9622 - prc: 0.8977
# Epoch 25: val_loss did not improve from 0.31267
# 12/12 [==============================] - 35s 3s/step - loss: 0.1429 - tp: 21438.0000 - fp: 13081.0000 - tn: 177638.0000 - fn: 843.0000 - accuracy: 0.9346 - precision: 0.6210 - recall: 0.9622 - prc: 0.8977 - val_loss: 0.4801 - val_tp: 3021.0000 - val_fp: 7442.0000 - val_tn: 25684.0000 - val_fn: 453.0000 - val_accuracy: 0.7843 - val_precision: 0.2887 - val_recall: 0.8696 - val_prc: 0.5660
# Epoch 26/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1585 - tp: 21225.0000 - fp: 13045.0000 - tn: 177674.0000 - fn: 1056.0000 - accuracy: 0.9338 - precision: 0.6193 - recall: 0.9526 - prc: 0.8634
# Epoch 26: val_loss did not improve from 0.31267
# 12/12 [==============================] - 35s 3s/step - loss: 0.1585 - tp: 21225.0000 - fp: 13045.0000 - tn: 177674.0000 - fn: 1056.0000 - accuracy: 0.9338 - precision: 0.6193 - recall: 0.9526 - prc: 0.8634 - val_loss: 0.3439 - val_tp: 3327.0000 - val_fp: 5042.0000 - val_tn: 28084.0000 - val_fn: 147.0000 - val_accuracy: 0.8582 - val_precision: 0.3975 - val_recall: 0.9577 - val_prc: 0.7992
# Epoch 27/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1345 - tp: 21552.0000 - fp: 11903.0000 - tn: 178816.0000 - fn: 729.0000 - accuracy: 0.9407 - precision: 0.6442 - recall: 0.9673 - prc: 0.9012
# Epoch 27: val_loss did not improve from 0.31267
# 12/12 [==============================] - 35s 3s/step - loss: 0.1345 - tp: 21552.0000 - fp: 11903.0000 - tn: 178816.0000 - fn: 729.0000 - accuracy: 0.9407 - precision: 0.6442 - recall: 0.9673 - prc: 0.9012 - val_loss: 0.4209 - val_tp: 3060.0000 - val_fp: 6146.0000 - val_tn: 26980.0000 - val_fn: 414.0000 - val_accuracy: 0.8208 - val_precision: 0.3324 - val_recall: 0.8808 - val_prc: 0.5544
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1248 - tp: 21618.0000 - fp: 10503.0000 - tn: 180216.0000 - fn: 663.0000 - accuracy: 0.9476 - precision: 0.6730 - recall: 0.9702 - prc: 0.8696
# Epoch 28: val_loss improved from 0.31267 to 0.24765, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1248 - tp: 21618.0000 - fp: 10503.0000 - tn: 180216.0000 - fn: 663.0000 - accuracy: 0.9476 - precision: 0.6730 - recall: 0.9702 - prc: 0.8696 - val_loss: 0.2476 - val_tp: 3322.0000 - val_fp: 3718.0000 - val_tn: 29408.0000 - val_fn: 152.0000 - val_accuracy: 0.8943 - val_precision: 0.4719 - val_recall: 0.9562 - val_prc: 0.8057
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1183 - tp: 21378.0000 - fp: 8042.0000 - tn: 182677.0000 - fn: 903.0000 - accuracy: 0.9580 - precision: 0.7266 - recall: 0.9595 - prc: 0.9296
# Epoch 29: val_loss did not improve from 0.24765
# 12/12 [==============================] - 35s 3s/step - loss: 0.1183 - tp: 21378.0000 - fp: 8042.0000 - tn: 182677.0000 - fn: 903.0000 - accuracy: 0.9580 - precision: 0.7266 - recall: 0.9595 - prc: 0.9296 - val_loss: 0.2720 - val_tp: 3363.0000 - val_fp: 3819.0000 - val_tn: 29307.0000 - val_fn: 111.0000 - val_accuracy: 0.8926 - val_precision: 0.4683 - val_recall: 0.9680 - val_prc: 0.8421
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1203 - tp: 21611.0000 - fp: 11061.0000 - tn: 179658.0000 - fn: 670.0000 - accuracy: 0.9449 - precision: 0.6615 - recall: 0.9699 - prc: 0.9116
# Epoch 30: val_loss improved from 0.24765 to 0.16033, saving model to tcn12_aumented_grooming.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1203 - tp: 21611.0000 - fp: 11061.0000 - tn: 179658.0000 - fn: 670.0000 - accuracy: 0.9449 - precision: 0.6615 - recall: 0.9699 - prc: 0.9116 - val_loss: 0.1603 - val_tp: 3158.0000 - val_fp: 2108.0000 - val_tn: 31018.0000 - val_fn: 316.0000 - val_accuracy: 0.9338 - val_precision: 0.5997 - val_recall: 0.9090 - val_prc: 0.8262
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1882 - tp: 21161.0000 - fp: 17294.0000 - tn: 173425.0000 - fn: 1120.0000 - accuracy: 0.9135 - precision: 0.5503 - recall: 0.9497 - prc: 0.8469
# Epoch 31: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1882 - tp: 21161.0000 - fp: 17294.0000 - tn: 173425.0000 - fn: 1120.0000 - accuracy: 0.9135 - precision: 0.5503 - recall: 0.9497 - prc: 0.8469 - val_loss: 0.2959 - val_tp: 2656.0000 - val_fp: 3986.0000 - val_tn: 29140.0000 - val_fn: 818.0000 - val_accuracy: 0.8687 - val_precision: 0.3999 - val_recall: 0.7645 - val_prc: 0.5478
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2636 - tp: 20847.0000 - fp: 19627.0000 - tn: 171092.0000 - fn: 1434.0000 - accuracy: 0.9011 - precision: 0.5151 - recall: 0.9356 - prc: 0.6671
# Epoch 32: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2636 - tp: 20847.0000 - fp: 19627.0000 - tn: 171092.0000 - fn: 1434.0000 - accuracy: 0.9011 - precision: 0.5151 - recall: 0.9356 - prc: 0.6671 - val_loss: 1.1456 - val_tp: 1475.0000 - val_fp: 6261.0000 - val_tn: 26865.0000 - val_fn: 1999.0000 - val_accuracy: 0.7743 - val_precision: 0.1907 - val_recall: 0.4246 - val_prc: 0.1893
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1914 - tp: 20660.0000 - fp: 13853.0000 - tn: 176866.0000 - fn: 1621.0000 - accuracy: 0.9274 - precision: 0.5986 - recall: 0.9272 - prc: 0.8273
# Epoch 33: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1914 - tp: 20660.0000 - fp: 13853.0000 - tn: 176866.0000 - fn: 1621.0000 - accuracy: 0.9274 - precision: 0.5986 - recall: 0.9272 - prc: 0.8273 - val_loss: 0.4929 - val_tp: 1035.0000 - val_fp: 2218.0000 - val_tn: 30908.0000 - val_fn: 2439.0000 - val_accuracy: 0.8728 - val_precision: 0.3182 - val_recall: 0.2979 - val_prc: 0.2606
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2301 - tp: 21355.0000 - fp: 24561.0000 - tn: 166158.0000 - fn: 926.0000 - accuracy: 0.8803 - precision: 0.4651 - recall: 0.9584 - prc: 0.7652
# Epoch 34: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2301 - tp: 21355.0000 - fp: 24561.0000 - tn: 166158.0000 - fn: 926.0000 - accuracy: 0.8803 - precision: 0.4651 - recall: 0.9584 - prc: 0.7652 - val_loss: 1.9627 - val_tp: 3418.0000 - val_fp: 10779.0000 - val_tn: 22347.0000 - val_fn: 56.0000 - val_accuracy: 0.7040 - val_precision: 0.2408 - val_recall: 0.9839 - val_prc: 0.3778
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1744 - tp: 20655.0000 - fp: 11246.0000 - tn: 179473.0000 - fn: 1626.0000 - accuracy: 0.9396 - precision: 0.6475 - recall: 0.9270 - prc: 0.8607
# Epoch 35: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1744 - tp: 20655.0000 - fp: 11246.0000 - tn: 179473.0000 - fn: 1626.0000 - accuracy: 0.9396 - precision: 0.6475 - recall: 0.9270 - prc: 0.8607 - val_loss: 1.2533 - val_tp: 3354.0000 - val_fp: 5728.0000 - val_tn: 27398.0000 - val_fn: 120.0000 - val_accuracy: 0.8402 - val_precision: 0.3693 - val_recall: 0.9655 - val_prc: 0.4735
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3258 - tp: 20588.0000 - fp: 25908.0000 - tn: 164811.0000 - fn: 1693.0000 - accuracy: 0.8704 - precision: 0.4428 - recall: 0.9240 - prc: 0.6554
# Epoch 36: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.3258 - tp: 20588.0000 - fp: 25908.0000 - tn: 164811.0000 - fn: 1693.0000 - accuracy: 0.8704 - precision: 0.4428 - recall: 0.9240 - prc: 0.6554 - val_loss: 2.4989 - val_tp: 3295.0000 - val_fp: 11898.0000 - val_tn: 21228.0000 - val_fn: 179.0000 - val_accuracy: 0.6700 - val_precision: 0.2169 - val_recall: 0.9485 - val_prc: 0.2763
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4418 - tp: 20000.0000 - fp: 43089.0000 - tn: 147630.0000 - fn: 2281.0000 - accuracy: 0.7870 - precision: 0.3170 - recall: 0.8976 - prc: 0.5210
# Epoch 37: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.4418 - tp: 20000.0000 - fp: 43089.0000 - tn: 147630.0000 - fn: 2281.0000 - accuracy: 0.7870 - precision: 0.3170 - recall: 0.8976 - prc: 0.5210 - val_loss: 1.6508 - val_tp: 1521.0000 - val_fp: 9975.0000 - val_tn: 23151.0000 - val_fn: 1953.0000 - val_accuracy: 0.6741 - val_precision: 0.1323 - val_recall: 0.4378 - val_prc: 0.1566
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2714 - tp: 19997.0000 - fp: 20524.0000 - tn: 170195.0000 - fn: 2284.0000 - accuracy: 0.8929 - precision: 0.4935 - recall: 0.8975 - prc: 0.7262
# Epoch 38: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2714 - tp: 19997.0000 - fp: 20524.0000 - tn: 170195.0000 - fn: 2284.0000 - accuracy: 0.8929 - precision: 0.4935 - recall: 0.8975 - prc: 0.7262 - val_loss: 6.5793 - val_tp: 3449.0000 - val_fp: 25706.0000 - val_tn: 7420.0000 - val_fn: 25.0000 - val_accuracy: 0.2970 - val_precision: 0.1183 - val_recall: 0.9928 - val_prc: 0.1595
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2295 - tp: 20747.0000 - fp: 17927.0000 - tn: 172792.0000 - fn: 1534.0000 - accuracy: 0.9086 - precision: 0.5365 - recall: 0.9312 - prc: 0.7467
# Epoch 39: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2295 - tp: 20747.0000 - fp: 17927.0000 - tn: 172792.0000 - fn: 1534.0000 - accuracy: 0.9086 - precision: 0.5365 - recall: 0.9312 - prc: 0.7467 - val_loss: 2.8449 - val_tp: 3431.0000 - val_fp: 13793.0000 - val_tn: 19333.0000 - val_fn: 43.0000 - val_accuracy: 0.6220 - val_precision: 0.1992 - val_recall: 0.9876 - val_prc: 0.3052
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2075 - tp: 20584.0000 - fp: 13824.0000 - tn: 176895.0000 - fn: 1697.0000 - accuracy: 0.9271 - precision: 0.5982 - recall: 0.9238 - prc: 0.8043
# Epoch 40: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2075 - tp: 20584.0000 - fp: 13824.0000 - tn: 176895.0000 - fn: 1697.0000 - accuracy: 0.9271 - precision: 0.5982 - recall: 0.9238 - prc: 0.8043 - val_loss: 0.5386 - val_tp: 2832.0000 - val_fp: 3745.0000 - val_tn: 29381.0000 - val_fn: 642.0000 - val_accuracy: 0.8801 - val_precision: 0.4306 - val_recall: 0.8152 - val_prc: 0.5641
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1946 - tp: 20892.0000 - fp: 15576.0000 - tn: 175143.0000 - fn: 1389.0000 - accuracy: 0.9204 - precision: 0.5729 - recall: 0.9377 - prc: 0.8344
# Epoch 41: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1946 - tp: 20892.0000 - fp: 15576.0000 - tn: 175143.0000 - fn: 1389.0000 - accuracy: 0.9204 - precision: 0.5729 - recall: 0.9377 - prc: 0.8344 - val_loss: 0.4013 - val_tp: 3124.0000 - val_fp: 2575.0000 - val_tn: 30551.0000 - val_fn: 350.0000 - val_accuracy: 0.9201 - val_precision: 0.5482 - val_recall: 0.8993 - val_prc: 0.6909
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1745 - tp: 20783.0000 - fp: 10852.0000 - tn: 179867.0000 - fn: 1498.0000 - accuracy: 0.9420 - precision: 0.6570 - recall: 0.9328 - prc: 0.8590
# Epoch 42: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1745 - tp: 20783.0000 - fp: 10852.0000 - tn: 179867.0000 - fn: 1498.0000 - accuracy: 0.9420 - precision: 0.6570 - recall: 0.9328 - prc: 0.8590 - val_loss: 0.2183 - val_tp: 2547.0000 - val_fp: 1816.0000 - val_tn: 31310.0000 - val_fn: 927.0000 - val_accuracy: 0.9251 - val_precision: 0.5838 - val_recall: 0.7332 - val_prc: 0.6242
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1678 - tp: 21099.0000 - fp: 13305.0000 - tn: 177414.0000 - fn: 1182.0000 - accuracy: 0.9320 - precision: 0.6133 - recall: 0.9470 - prc: 0.8692
# Epoch 43: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1678 - tp: 21099.0000 - fp: 13305.0000 - tn: 177414.0000 - fn: 1182.0000 - accuracy: 0.9320 - precision: 0.6133 - recall: 0.9470 - prc: 0.8692 - val_loss: 0.2030 - val_tp: 2990.0000 - val_fp: 1819.0000 - val_tn: 31307.0000 - val_fn: 484.0000 - val_accuracy: 0.9371 - val_precision: 0.6218 - val_recall: 0.8607 - val_prc: 0.7627
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2458 - tp: 21400.0000 - fp: 26773.0000 - tn: 163946.0000 - fn: 881.0000 - accuracy: 0.8702 - precision: 0.4442 - recall: 0.9605 - prc: 0.7769
# Epoch 44: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2458 - tp: 21400.0000 - fp: 26773.0000 - tn: 163946.0000 - fn: 881.0000 - accuracy: 0.8702 - precision: 0.4442 - recall: 0.9605 - prc: 0.7769 - val_loss: 0.7201 - val_tp: 1575.0000 - val_fp: 4417.0000 - val_tn: 28709.0000 - val_fn: 1899.0000 - val_accuracy: 0.8274 - val_precision: 0.2629 - val_recall: 0.4534 - val_prc: 0.2865
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2371 - tp: 20085.0000 - fp: 14573.0000 - tn: 176146.0000 - fn: 2196.0000 - accuracy: 0.9213 - precision: 0.5795 - recall: 0.9014 - prc: 0.7638
# Epoch 45: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2371 - tp: 20085.0000 - fp: 14573.0000 - tn: 176146.0000 - fn: 2196.0000 - accuracy: 0.9213 - precision: 0.5795 - recall: 0.9014 - prc: 0.7638 - val_loss: 1.3198 - val_tp: 3345.0000 - val_fp: 12478.0000 - val_tn: 20648.0000 - val_fn: 129.0000 - val_accuracy: 0.6555 - val_precision: 0.2114 - val_recall: 0.9629 - val_prc: 0.4663
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2045 - tp: 20988.0000 - fp: 18598.0000 - tn: 172121.0000 - fn: 1293.0000 - accuracy: 0.9066 - precision: 0.5302 - recall: 0.9420 - prc: 0.8192
# Epoch 46: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2045 - tp: 20988.0000 - fp: 18598.0000 - tn: 172121.0000 - fn: 1293.0000 - accuracy: 0.9066 - precision: 0.5302 - recall: 0.9420 - prc: 0.8192 - val_loss: 1.1234 - val_tp: 3420.0000 - val_fp: 11941.0000 - val_tn: 21185.0000 - val_fn: 54.0000 - val_accuracy: 0.6723 - val_precision: 0.2226 - val_recall: 0.9845 - val_prc: 0.5529
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3529 - tp: 21599.0000 - fp: 43450.0000 - tn: 147269.0000 - fn: 682.0000 - accuracy: 0.7928 - precision: 0.3320 - recall: 0.9694 - prc: 0.6799
# Epoch 47: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.3529 - tp: 21599.0000 - fp: 43450.0000 - tn: 147269.0000 - fn: 682.0000 - accuracy: 0.7928 - precision: 0.3320 - recall: 0.9694 - prc: 0.6799 - val_loss: 3.2342 - val_tp: 3466.0000 - val_fp: 25643.0000 - val_tn: 7483.0000 - val_fn: 8.0000 - val_accuracy: 0.2992 - val_precision: 0.1191 - val_recall: 0.9977 - val_prc: 0.2876
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2311 - tp: 19770.0000 - fp: 11520.0000 - tn: 179199.0000 - fn: 2511.0000 - accuracy: 0.9341 - precision: 0.6318 - recall: 0.8873 - prc: 0.8089
# Epoch 48: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2311 - tp: 19770.0000 - fp: 11520.0000 - tn: 179199.0000 - fn: 2511.0000 - accuracy: 0.9341 - precision: 0.6318 - recall: 0.8873 - prc: 0.8089 - val_loss: 3.6645 - val_tp: 3458.0000 - val_fp: 20734.0000 - val_tn: 12392.0000 - val_fn: 16.0000 - val_accuracy: 0.4331 - val_precision: 0.1429 - val_recall: 0.9954 - val_prc: 0.2732
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2105 - tp: 21009.0000 - fp: 17720.0000 - tn: 172999.0000 - fn: 1272.0000 - accuracy: 0.9108 - precision: 0.5425 - recall: 0.9429 - prc: 0.8220
# Epoch 49: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.2105 - tp: 21009.0000 - fp: 17720.0000 - tn: 172999.0000 - fn: 1272.0000 - accuracy: 0.9108 - precision: 0.5425 - recall: 0.9429 - prc: 0.8220 - val_loss: 1.8171 - val_tp: 3453.0000 - val_fp: 13041.0000 - val_tn: 20085.0000 - val_fn: 21.0000 - val_accuracy: 0.6431 - val_precision: 0.2093 - val_recall: 0.9940 - val_prc: 0.4197
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1992 - tp: 20675.0000 - fp: 13507.0000 - tn: 177212.0000 - fn: 1606.0000 - accuracy: 0.9290 - precision: 0.6049 - recall: 0.9279 - prc: 0.8332
# Epoch 50: val_loss did not improve from 0.16033
# 12/12 [==============================] - 35s 3s/step - loss: 0.1992 - tp: 20675.0000 - fp: 13507.0000 - tn: 177212.0000 - fn: 1606.0000 - accuracy: 0.9290 - precision: 0.6049 - recall: 0.9279 - prc: 0.8332 - val_loss: 1.4251 - val_tp: 3442.0000 - val_fp: 9128.0000 - val_tn: 23998.0000 - val_fn: 32.0000 - val_accuracy: 0.7497 - val_precision: 0.2738 - val_recall: 0.9908 - val_prc: 0.4680
# Results:
# 	Loss: 0.1603347212076187
# 	TruePositives: 3158.0
# 	FalsePositives: 2108.0
# 	TrueNegatives: 31018.0
# 	FalseNegatives: 316.0
# 	Accuracy: 0.9337705373764038
# 	Precision: 0.599696159362793
# 	Recall: 0.9090386033058167
# 	PRC: 0.8262084722518921
# 12/12 [==============================] - 15s 1s/step
# 2/2 [==============================] - 3s 2s/step
# Running experiment for Rearing
# /Users/saraalbarran/Documents/SARA/ratolins/AutomatedMouseBehaviorRecognition/notebooks/utils2.py:386: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_metrics = pd.concat([
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 1.1848 - tp: 26613.0000 - fp: 75639.0000 - tn: 89444.0000 - fn: 21304.0000 - accuracy: 0.5449 - precision: 0.2603 - recall: 0.5554 - prc: 0.2652
# Epoch 1: val_loss improved from inf to 1.48734, saving model to tcn12_aumented_rearing.h5
# /Users/saraalbarran/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12/12 [==============================] - 60s 4s/step - loss: 1.1848 - tp: 26613.0000 - fp: 75639.0000 - tn: 89444.0000 - fn: 21304.0000 - accuracy: 0.5449 - precision: 0.2603 - recall: 0.5554 - prc: 0.2652 - val_loss: 1.4873 - val_tp: 33.0000 - val_fp: 121.0000 - val_tn: 32780.0000 - val_fn: 3666.0000 - val_accuracy: 0.8965 - val_precision: 0.2143 - val_recall: 0.0089 - val_prc: 0.1049
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7419 - tp: 31224.0000 - fp: 55282.0000 - tn: 109801.0000 - fn: 16693.0000 - accuracy: 0.6621 - precision: 0.3609 - recall: 0.6516 - prc: 0.4221
# Epoch 2: val_loss improved from 1.48734 to 1.27670, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 38s 3s/step - loss: 0.7419 - tp: 31224.0000 - fp: 55282.0000 - tn: 109801.0000 - fn: 16693.0000 - accuracy: 0.6621 - precision: 0.3609 - recall: 0.6516 - prc: 0.4221 - val_loss: 1.2767 - val_tp: 683.0000 - val_fp: 4809.0000 - val_tn: 28092.0000 - val_fn: 3016.0000 - val_accuracy: 0.7862 - val_precision: 0.1244 - val_recall: 0.1846 - val_prc: 0.1170
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6169 - tp: 32170.0000 - fp: 39346.0000 - tn: 125737.0000 - fn: 15747.0000 - accuracy: 0.7413 - precision: 0.4498 - recall: 0.6714 - prc: 0.5380
# Epoch 3: val_loss improved from 1.27670 to 0.54075, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 37s 3s/step - loss: 0.6169 - tp: 32170.0000 - fp: 39346.0000 - tn: 125737.0000 - fn: 15747.0000 - accuracy: 0.7413 - precision: 0.4498 - recall: 0.6714 - prc: 0.5380 - val_loss: 0.5408 - val_tp: 722.0000 - val_fp: 1465.0000 - val_tn: 31436.0000 - val_fn: 2977.0000 - val_accuracy: 0.8786 - val_precision: 0.3301 - val_recall: 0.1952 - val_prc: 0.2545
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5033 - tp: 35820.0000 - fp: 37418.0000 - tn: 127665.0000 - fn: 12097.0000 - accuracy: 0.7675 - precision: 0.4891 - recall: 0.7475 - prc: 0.6448
# Epoch 4: val_loss did not improve from 0.54075
# 12/12 [==============================] - 36s 3s/step - loss: 0.5033 - tp: 35820.0000 - fp: 37418.0000 - tn: 127665.0000 - fn: 12097.0000 - accuracy: 0.7675 - precision: 0.4891 - recall: 0.7475 - prc: 0.6448 - val_loss: 1.0926 - val_tp: 3136.0000 - val_fp: 13883.0000 - val_tn: 19018.0000 - val_fn: 563.0000 - val_accuracy: 0.6053 - val_precision: 0.1843 - val_recall: 0.8478 - val_prc: 0.2683
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5184 - tp: 37539.0000 - fp: 42874.0000 - tn: 122209.0000 - fn: 10378.0000 - accuracy: 0.7500 - precision: 0.4668 - recall: 0.7834 - prc: 0.6254
# Epoch 5: val_loss did not improve from 0.54075
# 12/12 [==============================] - 36s 3s/step - loss: 0.5184 - tp: 37539.0000 - fp: 42874.0000 - tn: 122209.0000 - fn: 10378.0000 - accuracy: 0.7500 - precision: 0.4668 - recall: 0.7834 - prc: 0.6254 - val_loss: 2.8190 - val_tp: 2341.0000 - val_fp: 10481.0000 - val_tn: 22420.0000 - val_fn: 1358.0000 - val_accuracy: 0.6765 - val_precision: 0.1826 - val_recall: 0.6329 - val_prc: 0.1553
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4607 - tp: 38992.0000 - fp: 37690.0000 - tn: 127393.0000 - fn: 8925.0000 - accuracy: 0.7812 - precision: 0.5085 - recall: 0.8137 - prc: 0.6884
# Epoch 6: val_loss did not improve from 0.54075
# 12/12 [==============================] - 36s 3s/step - loss: 0.4607 - tp: 38992.0000 - fp: 37690.0000 - tn: 127393.0000 - fn: 8925.0000 - accuracy: 0.7812 - precision: 0.5085 - recall: 0.8137 - prc: 0.6884 - val_loss: 0.5470 - val_tp: 2059.0000 - val_fp: 3220.0000 - val_tn: 29681.0000 - val_fn: 1640.0000 - val_accuracy: 0.8672 - val_precision: 0.3900 - val_recall: 0.5566 - val_prc: 0.4239
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4692 - tp: 38395.0000 - fp: 37734.0000 - tn: 127349.0000 - fn: 9522.0000 - accuracy: 0.7781 - precision: 0.5043 - recall: 0.8013 - prc: 0.6677
# Epoch 7: val_loss improved from 0.54075 to 0.47997, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.4692 - tp: 38395.0000 - fp: 37734.0000 - tn: 127349.0000 - fn: 9522.0000 - accuracy: 0.7781 - precision: 0.5043 - recall: 0.8013 - prc: 0.6677 - val_loss: 0.4800 - val_tp: 2785.0000 - val_fp: 5419.0000 - val_tn: 27482.0000 - val_fn: 914.0000 - val_accuracy: 0.8270 - val_precision: 0.3395 - val_recall: 0.7529 - val_prc: 0.4886
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4048 - tp: 38529.0000 - fp: 28909.0000 - tn: 136174.0000 - fn: 9388.0000 - accuracy: 0.8202 - precision: 0.5713 - recall: 0.8041 - prc: 0.7419
# Epoch 8: val_loss did not improve from 0.47997
# 12/12 [==============================] - 35s 3s/step - loss: 0.4048 - tp: 38529.0000 - fp: 28909.0000 - tn: 136174.0000 - fn: 9388.0000 - accuracy: 0.8202 - precision: 0.5713 - recall: 0.8041 - prc: 0.7419 - val_loss: 0.6198 - val_tp: 2865.0000 - val_fp: 8064.0000 - val_tn: 24837.0000 - val_fn: 834.0000 - val_accuracy: 0.7569 - val_precision: 0.2621 - val_recall: 0.7745 - val_prc: 0.3589
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3902 - tp: 40194.0000 - fp: 32804.0000 - tn: 132279.0000 - fn: 7723.0000 - accuracy: 0.8097 - precision: 0.5506 - recall: 0.8388 - prc: 0.7533
# Epoch 9: val_loss did not improve from 0.47997
# 12/12 [==============================] - 35s 3s/step - loss: 0.3902 - tp: 40194.0000 - fp: 32804.0000 - tn: 132279.0000 - fn: 7723.0000 - accuracy: 0.8097 - precision: 0.5506 - recall: 0.8388 - prc: 0.7533 - val_loss: 0.5695 - val_tp: 3301.0000 - val_fp: 9282.0000 - val_tn: 23619.0000 - val_fn: 398.0000 - val_accuracy: 0.7355 - val_precision: 0.2623 - val_recall: 0.8924 - val_prc: 0.5361
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3904 - tp: 39620.0000 - fp: 29994.0000 - tn: 135089.0000 - fn: 8297.0000 - accuracy: 0.8202 - precision: 0.5691 - recall: 0.8268 - prc: 0.7580
# Epoch 10: val_loss did not improve from 0.47997
# 12/12 [==============================] - 35s 3s/step - loss: 0.3904 - tp: 39620.0000 - fp: 29994.0000 - tn: 135089.0000 - fn: 8297.0000 - accuracy: 0.8202 - precision: 0.5691 - recall: 0.8268 - prc: 0.7580 - val_loss: 1.6503 - val_tp: 3530.0000 - val_fp: 20352.0000 - val_tn: 12549.0000 - val_fn: 169.0000 - val_accuracy: 0.4393 - val_precision: 0.1478 - val_recall: 0.9543 - val_prc: 0.2737
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3563 - tp: 39920.0000 - fp: 25958.0000 - tn: 139125.0000 - fn: 7997.0000 - accuracy: 0.8406 - precision: 0.6060 - recall: 0.8331 - prc: 0.7836
# Epoch 11: val_loss improved from 0.47997 to 0.46770, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.3563 - tp: 39920.0000 - fp: 25958.0000 - tn: 139125.0000 - fn: 7997.0000 - accuracy: 0.8406 - precision: 0.6060 - recall: 0.8331 - prc: 0.7836 - val_loss: 0.4677 - val_tp: 3029.0000 - val_fp: 6496.0000 - val_tn: 26405.0000 - val_fn: 670.0000 - val_accuracy: 0.8042 - val_precision: 0.3180 - val_recall: 0.8189 - val_prc: 0.5715
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3346 - tp: 41287.0000 - fp: 25433.0000 - tn: 139650.0000 - fn: 6630.0000 - accuracy: 0.8495 - precision: 0.6188 - recall: 0.8616 - prc: 0.8129
# Epoch 12: val_loss did not improve from 0.46770
# 12/12 [==============================] - 35s 3s/step - loss: 0.3346 - tp: 41287.0000 - fp: 25433.0000 - tn: 139650.0000 - fn: 6630.0000 - accuracy: 0.8495 - precision: 0.6188 - recall: 0.8616 - prc: 0.8129 - val_loss: 0.6695 - val_tp: 3229.0000 - val_fp: 10282.0000 - val_tn: 22619.0000 - val_fn: 470.0000 - val_accuracy: 0.7062 - val_precision: 0.2390 - val_recall: 0.8729 - val_prc: 0.5443
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2976 - tp: 42227.0000 - fp: 22530.0000 - tn: 142553.0000 - fn: 5690.0000 - accuracy: 0.8675 - precision: 0.6521 - recall: 0.8813 - prc: 0.8436
# Epoch 13: val_loss improved from 0.46770 to 0.32770, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.2976 - tp: 42227.0000 - fp: 22530.0000 - tn: 142553.0000 - fn: 5690.0000 - accuracy: 0.8675 - precision: 0.6521 - recall: 0.8813 - prc: 0.8436 - val_loss: 0.3277 - val_tp: 2279.0000 - val_fp: 3963.0000 - val_tn: 28938.0000 - val_fn: 1420.0000 - val_accuracy: 0.8529 - val_precision: 0.3651 - val_recall: 0.6161 - val_prc: 0.4558
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3440 - tp: 40762.0000 - fp: 24803.0000 - tn: 140280.0000 - fn: 7155.0000 - accuracy: 0.8500 - precision: 0.6217 - recall: 0.8507 - prc: 0.8025
# Epoch 14: val_loss did not improve from 0.32770
# 12/12 [==============================] - 35s 3s/step - loss: 0.3440 - tp: 40762.0000 - fp: 24803.0000 - tn: 140280.0000 - fn: 7155.0000 - accuracy: 0.8500 - precision: 0.6217 - recall: 0.8507 - prc: 0.8025 - val_loss: 0.8015 - val_tp: 3355.0000 - val_fp: 11694.0000 - val_tn: 21207.0000 - val_fn: 344.0000 - val_accuracy: 0.6711 - val_precision: 0.2229 - val_recall: 0.9070 - val_prc: 0.5017
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3072 - tp: 42309.0000 - fp: 24909.0000 - tn: 140174.0000 - fn: 5608.0000 - accuracy: 0.8567 - precision: 0.6294 - recall: 0.8830 - prc: 0.8349
# Epoch 15: val_loss did not improve from 0.32770
# 12/12 [==============================] - 35s 3s/step - loss: 0.3072 - tp: 42309.0000 - fp: 24909.0000 - tn: 140174.0000 - fn: 5608.0000 - accuracy: 0.8567 - precision: 0.6294 - recall: 0.8830 - prc: 0.8349 - val_loss: 0.5902 - val_tp: 2999.0000 - val_fp: 7738.0000 - val_tn: 25163.0000 - val_fn: 700.0000 - val_accuracy: 0.7695 - val_precision: 0.2793 - val_recall: 0.8108 - val_prc: 0.3862
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3163 - tp: 42295.0000 - fp: 24850.0000 - tn: 140233.0000 - fn: 5622.0000 - accuracy: 0.8569 - precision: 0.6299 - recall: 0.8827 - prc: 0.8154
# Epoch 16: val_loss did not improve from 0.32770
# 12/12 [==============================] - 35s 3s/step - loss: 0.3163 - tp: 42295.0000 - fp: 24850.0000 - tn: 140233.0000 - fn: 5622.0000 - accuracy: 0.8569 - precision: 0.6299 - recall: 0.8827 - prc: 0.8154 - val_loss: 0.3543 - val_tp: 2687.0000 - val_fp: 4404.0000 - val_tn: 28497.0000 - val_fn: 1012.0000 - val_accuracy: 0.8520 - val_precision: 0.3789 - val_recall: 0.7264 - val_prc: 0.5561
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3215 - tp: 41367.0000 - fp: 22531.0000 - tn: 142552.0000 - fn: 6550.0000 - accuracy: 0.8635 - precision: 0.6474 - recall: 0.8633 - prc: 0.8241
# Epoch 17: val_loss improved from 0.32770 to 0.26104, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.3215 - tp: 41367.0000 - fp: 22531.0000 - tn: 142552.0000 - fn: 6550.0000 - accuracy: 0.8635 - precision: 0.6474 - recall: 0.8633 - prc: 0.8241 - val_loss: 0.2610 - val_tp: 2602.0000 - val_fp: 2735.0000 - val_tn: 30166.0000 - val_fn: 1097.0000 - val_accuracy: 0.8953 - val_precision: 0.4875 - val_recall: 0.7034 - val_prc: 0.5986
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2970 - tp: 42476.0000 - fp: 23090.0000 - tn: 141993.0000 - fn: 5441.0000 - accuracy: 0.8661 - precision: 0.6478 - recall: 0.8864 - prc: 0.8450
# Epoch 18: val_loss did not improve from 0.26104
# 12/12 [==============================] - 35s 3s/step - loss: 0.2970 - tp: 42476.0000 - fp: 23090.0000 - tn: 141993.0000 - fn: 5441.0000 - accuracy: 0.8661 - precision: 0.6478 - recall: 0.8864 - prc: 0.8450 - val_loss: 0.2800 - val_tp: 2555.0000 - val_fp: 2187.0000 - val_tn: 30714.0000 - val_fn: 1144.0000 - val_accuracy: 0.9090 - val_precision: 0.5388 - val_recall: 0.6907 - val_prc: 0.6525
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3527 - tp: 41773.0000 - fp: 27707.0000 - tn: 137376.0000 - fn: 6144.0000 - accuracy: 0.8411 - precision: 0.6012 - recall: 0.8718 - prc: 0.7929
# Epoch 19: val_loss did not improve from 0.26104
# 12/12 [==============================] - 35s 3s/step - loss: 0.3527 - tp: 41773.0000 - fp: 27707.0000 - tn: 137376.0000 - fn: 6144.0000 - accuracy: 0.8411 - precision: 0.6012 - recall: 0.8718 - prc: 0.7929 - val_loss: 0.4431 - val_tp: 1854.0000 - val_fp: 2852.0000 - val_tn: 30049.0000 - val_fn: 1845.0000 - val_accuracy: 0.8717 - val_precision: 0.3940 - val_recall: 0.5012 - val_prc: 0.4017
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3012 - tp: 42769.0000 - fp: 24728.0000 - tn: 140355.0000 - fn: 5148.0000 - accuracy: 0.8597 - precision: 0.6336 - recall: 0.8926 - prc: 0.8482
# Epoch 20: val_loss did not improve from 0.26104
# ...
# Epoch 27: val_loss did not improve from 0.26104
# 12/12 [==============================] - 35s 3s/step - loss: 0.1484 - tp: 45580.0000 - fp: 10657.0000 - tn: 154426.0000 - fn: 2337.0000 - accuracy: 0.9390 - precision: 0.8105 - recall: 0.9512 - prc: 0.9504 - val_loss: 0.3154 - val_tp: 3182.0000 - val_fp: 3867.0000 - val_tn: 29034.0000 - val_fn: 517.0000 - val_accuracy: 0.8802 - val_precision: 0.4514 - val_recall: 0.8602 - val_prc: 0.6950
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1525 - tp: 45533.0000 - fp: 11243.0000 - tn: 153840.0000 - fn: 2384.0000 - accuracy: 0.9360 - precision: 0.8020 - recall: 0.9502 - prc: 0.9458
# Epoch 28: val_loss improved from 0.26104 to 0.21009, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1525 - tp: 45533.0000 - fp: 11243.0000 - tn: 153840.0000 - fn: 2384.0000 - accuracy: 0.9360 - precision: 0.8020 - recall: 0.9502 - prc: 0.9458 - val_loss: 0.2101 - val_tp: 2785.0000 - val_fp: 2086.0000 - val_tn: 30815.0000 - val_fn: 914.0000 - val_accuracy: 0.9180 - val_precision: 0.5718 - val_recall: 0.7529 - val_prc: 0.7012
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1506 - tp: 45136.0000 - fp: 9997.0000 - tn: 155086.0000 - fn: 2781.0000 - accuracy: 0.9400 - precision: 0.8187 - recall: 0.9420 - prc: 0.9508
# Epoch 29: val_loss did not improve from 0.21009
# 12/12 [==============================] - 36s 3s/step - loss: 0.1506 - tp: 45136.0000 - fp: 9997.0000 - tn: 155086.0000 - fn: 2781.0000 - accuracy: 0.9400 - precision: 0.8187 - recall: 0.9420 - prc: 0.9508 - val_loss: 0.3081 - val_tp: 3177.0000 - val_fp: 3798.0000 - val_tn: 29103.0000 - val_fn: 522.0000 - val_accuracy: 0.8820 - val_precision: 0.4555 - val_recall: 0.8589 - val_prc: 0.6935
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1204 - tp: 45719.0000 - fp: 7466.0000 - tn: 157617.0000 - fn: 2198.0000 - accuracy: 0.9546 - precision: 0.8596 - recall: 0.9541 - prc: 0.9670
# Epoch 30: val_loss did not improve from 0.21009
# 12/12 [==============================] - 36s 3s/step - loss: 0.1204 - tp: 45719.0000 - fp: 7466.0000 - tn: 157617.0000 - fn: 2198.0000 - accuracy: 0.9546 - precision: 0.8596 - recall: 0.9541 - prc: 0.9670 - val_loss: 0.2584 - val_tp: 2973.0000 - val_fp: 2913.0000 - val_tn: 29988.0000 - val_fn: 726.0000 - val_accuracy: 0.9006 - val_precision: 0.5051 - val_recall: 0.8037 - val_prc: 0.7088
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1021 - tp: 46590.0000 - fp: 7960.0000 - tn: 157123.0000 - fn: 1327.0000 - accuracy: 0.9564 - precision: 0.8541 - recall: 0.9723 - prc: 0.9758
# Epoch 31: val_loss improved from 0.21009 to 0.19089, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.1021 - tp: 46590.0000 - fp: 7960.0000 - tn: 157123.0000 - fn: 1327.0000 - accuracy: 0.9564 - precision: 0.8541 - recall: 0.9723 - prc: 0.9758 - val_loss: 0.1909 - val_tp: 2683.0000 - val_fp: 1686.0000 - val_tn: 31215.0000 - val_fn: 1016.0000 - val_accuracy: 0.9262 - val_precision: 0.6141 - val_recall: 0.7253 - val_prc: 0.7298
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0881 - tp: 46629.0000 - fp: 6270.0000 - tn: 158813.0000 - fn: 1288.0000 - accuracy: 0.9645 - precision: 0.8815 - recall: 0.9731 - prc: 0.9821
# Epoch 32: val_loss did not improve from 0.19089
# 12/12 [==============================] - 35s 3s/step - loss: 0.0881 - tp: 46629.0000 - fp: 6270.0000 - tn: 158813.0000 - fn: 1288.0000 - accuracy: 0.9645 - precision: 0.8815 - recall: 0.9731 - prc: 0.9821 - val_loss: 0.2145 - val_tp: 2757.0000 - val_fp: 2100.0000 - val_tn: 30801.0000 - val_fn: 942.0000 - val_accuracy: 0.9169 - val_precision: 0.5676 - val_recall: 0.7453 - val_prc: 0.7093
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0901 - tp: 46304.0000 - fp: 5284.0000 - tn: 159799.0000 - fn: 1613.0000 - accuracy: 0.9676 - precision: 0.8976 - recall: 0.9663 - prc: 0.9822
# Epoch 33: val_loss did not improve from 0.19089
# 12/12 [==============================] - 36s 3s/step - loss: 0.0901 - tp: 46304.0000 - fp: 5284.0000 - tn: 159799.0000 - fn: 1613.0000 - accuracy: 0.9676 - precision: 0.8976 - recall: 0.9663 - prc: 0.9822 - val_loss: 0.2806 - val_tp: 3077.0000 - val_fp: 3000.0000 - val_tn: 29901.0000 - val_fn: 622.0000 - val_accuracy: 0.9010 - val_precision: 0.5063 - val_recall: 0.8318 - val_prc: 0.7052
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0880 - tp: 46538.0000 - fp: 6199.0000 - tn: 158884.0000 - fn: 1379.0000 - accuracy: 0.9644 - precision: 0.8825 - recall: 0.9712 - prc: 0.9807
# Epoch 34: val_loss did not improve from 0.19089
# 12/12 [==============================] - 35s 3s/step - loss: 0.0880 - tp: 46538.0000 - fp: 6199.0000 - tn: 158884.0000 - fn: 1379.0000 - accuracy: 0.9644 - precision: 0.8825 - recall: 0.9712 - prc: 0.9807 - val_loss: 0.2316 - val_tp: 3111.0000 - val_fp: 2574.0000 - val_tn: 30327.0000 - val_fn: 588.0000 - val_accuracy: 0.9136 - val_precision: 0.5472 - val_recall: 0.8410 - val_prc: 0.7405
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0752 - tp: 46954.0000 - fp: 5718.0000 - tn: 159365.0000 - fn: 963.0000 - accuracy: 0.9686 - precision: 0.8914 - recall: 0.9799 - prc: 0.9865
# Epoch 35: val_loss improved from 0.19089 to 0.18224, saving model to tcn12_aumented_rearing.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.0752 - tp: 46954.0000 - fp: 5718.0000 - tn: 159365.0000 - fn: 963.0000 - accuracy: 0.9686 - precision: 0.8914 - recall: 0.9799 - prc: 0.9865 - val_loss: 0.1822 - val_tp: 2668.0000 - val_fp: 1382.0000 - val_tn: 31519.0000 - val_fn: 1031.0000 - val_accuracy: 0.9341 - val_precision: 0.6588 - val_recall: 0.7213 - val_prc: 0.7443
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0692 - tp: 46711.0000 - fp: 4210.0000 - tn: 160873.0000 - fn: 1206.0000 - accuracy: 0.9746 - precision: 0.9173 - recall: 0.9748 - prc: 0.9883
# Epoch 36: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0692 - tp: 46711.0000 - fp: 4210.0000 - tn: 160873.0000 - fn: 1206.0000 - accuracy: 0.9746 - precision: 0.9173 - recall: 0.9748 - prc: 0.9883 - val_loss: 0.2067 - val_tp: 2557.0000 - val_fp: 1277.0000 - val_tn: 31624.0000 - val_fn: 1142.0000 - val_accuracy: 0.9339 - val_precision: 0.6669 - val_recall: 0.6913 - val_prc: 0.7258
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0712 - tp: 47012.0000 - fp: 5503.0000 - tn: 159580.0000 - fn: 905.0000 - accuracy: 0.9699 - precision: 0.8952 - recall: 0.9811 - prc: 0.9868
# Epoch 37: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0712 - tp: 47012.0000 - fp: 5503.0000 - tn: 159580.0000 - fn: 905.0000 - accuracy: 0.9699 - precision: 0.8952 - recall: 0.9811 - prc: 0.9868 - val_loss: 0.2219 - val_tp: 2808.0000 - val_fp: 1950.0000 - val_tn: 30951.0000 - val_fn: 891.0000 - val_accuracy: 0.9224 - val_precision: 0.5902 - val_recall: 0.7591 - val_prc: 0.7360
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0640 - tp: 47059.0000 - fp: 4519.0000 - tn: 160564.0000 - fn: 858.0000 - accuracy: 0.9748 - precision: 0.9124 - recall: 0.9821 - prc: 0.9894
# Epoch 38: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0640 - tp: 47059.0000 - fp: 4519.0000 - tn: 160564.0000 - fn: 858.0000 - accuracy: 0.9748 - precision: 0.9124 - recall: 0.9821 - prc: 0.9894 - val_loss: 0.2160 - val_tp: 3042.0000 - val_fp: 2371.0000 - val_tn: 30530.0000 - val_fn: 657.0000 - val_accuracy: 0.9173 - val_precision: 0.5620 - val_recall: 0.8224 - val_prc: 0.7713
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0694 - tp: 46894.0000 - fp: 4688.0000 - tn: 160395.0000 - fn: 1023.0000 - accuracy: 0.9732 - precision: 0.9091 - recall: 0.9787 - prc: 0.9878
# Epoch 39: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0694 - tp: 46894.0000 - fp: 4688.0000 - tn: 160395.0000 - fn: 1023.0000 - accuracy: 0.9732 - precision: 0.9091 - recall: 0.9787 - prc: 0.9878 - val_loss: 0.2013 - val_tp: 2703.0000 - val_fp: 1431.0000 - val_tn: 31470.0000 - val_fn: 996.0000 - val_accuracy: 0.9337 - val_precision: 0.6538 - val_recall: 0.7307 - val_prc: 0.7454
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0724 - tp: 46701.0000 - fp: 4537.0000 - tn: 160546.0000 - fn: 1216.0000 - accuracy: 0.9730 - precision: 0.9115 - recall: 0.9746 - prc: 0.9873
# Epoch 40: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0724 - tp: 46701.0000 - fp: 4537.0000 - tn: 160546.0000 - fn: 1216.0000 - accuracy: 0.9730 - precision: 0.9115 - recall: 0.9746 - prc: 0.9873 - val_loss: 0.2285 - val_tp: 2791.0000 - val_fp: 1551.0000 - val_tn: 31350.0000 - val_fn: 908.0000 - val_accuracy: 0.9328 - val_precision: 0.6428 - val_recall: 0.7545 - val_prc: 0.7419
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0847 - tp: 46702.0000 - fp: 6324.0000 - tn: 158759.0000 - fn: 1215.0000 - accuracy: 0.9646 - precision: 0.8807 - recall: 0.9746 - prc: 0.9818
# Epoch 41: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0847 - tp: 46702.0000 - fp: 6324.0000 - tn: 158759.0000 - fn: 1215.0000 - accuracy: 0.9646 - precision: 0.8807 - recall: 0.9746 - prc: 0.9818 - val_loss: 0.2091 - val_tp: 2527.0000 - val_fp: 1284.0000 - val_tn: 31617.0000 - val_fn: 1172.0000 - val_accuracy: 0.9329 - val_precision: 0.6631 - val_recall: 0.6832 - val_prc: 0.7052
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0669 - tp: 46870.0000 - fp: 4441.0000 - tn: 160642.0000 - fn: 1047.0000 - accuracy: 0.9742 - precision: 0.9134 - recall: 0.9781 - prc: 0.9880
# Epoch 42: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0669 - tp: 46870.0000 - fp: 4441.0000 - tn: 160642.0000 - fn: 1047.0000 - accuracy: 0.9742 - precision: 0.9134 - recall: 0.9781 - prc: 0.9880 - val_loss: 0.2714 - val_tp: 3033.0000 - val_fp: 2791.0000 - val_tn: 30110.0000 - val_fn: 666.0000 - val_accuracy: 0.9055 - val_precision: 0.5208 - val_recall: 0.8200 - val_prc: 0.7000
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0636 - tp: 46903.0000 - fp: 4184.0000 - tn: 160899.0000 - fn: 1014.0000 - accuracy: 0.9756 - precision: 0.9181 - recall: 0.9788 - prc: 0.9896
# Epoch 43: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0636 - tp: 46903.0000 - fp: 4184.0000 - tn: 160899.0000 - fn: 1014.0000 - accuracy: 0.9756 - precision: 0.9181 - recall: 0.9788 - prc: 0.9896 - val_loss: 0.3088 - val_tp: 3302.0000 - val_fp: 3562.0000 - val_tn: 29339.0000 - val_fn: 397.0000 - val_accuracy: 0.8918 - val_precision: 0.4811 - val_recall: 0.8927 - val_prc: 0.7444
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0561 - tp: 47242.0000 - fp: 4393.0000 - tn: 160690.0000 - fn: 675.0000 - accuracy: 0.9762 - precision: 0.9149 - recall: 0.9859 - prc: 0.9913
# Epoch 44: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0561 - tp: 47242.0000 - fp: 4393.0000 - tn: 160690.0000 - fn: 675.0000 - accuracy: 0.9762 - precision: 0.9149 - recall: 0.9859 - prc: 0.9913 - val_loss: 0.3461 - val_tp: 3212.0000 - val_fp: 3787.0000 - val_tn: 29114.0000 - val_fn: 487.0000 - val_accuracy: 0.8832 - val_precision: 0.4589 - val_recall: 0.8683 - val_prc: 0.7143
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0987 - tp: 46315.0000 - fp: 6457.0000 - tn: 158626.0000 - fn: 1602.0000 - accuracy: 0.9622 - precision: 0.8776 - recall: 0.9666 - prc: 0.9739
# Epoch 45: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0987 - tp: 46315.0000 - fp: 6457.0000 - tn: 158626.0000 - fn: 1602.0000 - accuracy: 0.9622 - precision: 0.8776 - recall: 0.9666 - prc: 0.9739 - val_loss: 0.3303 - val_tp: 2994.0000 - val_fp: 3419.0000 - val_tn: 29482.0000 - val_fn: 705.0000 - val_accuracy: 0.8873 - val_precision: 0.4669 - val_recall: 0.8094 - val_prc: 0.6689
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0884 - tp: 46548.0000 - fp: 6153.0000 - tn: 158930.0000 - fn: 1369.0000 - accuracy: 0.9647 - precision: 0.8832 - recall: 0.9714 - prc: 0.9794
# Epoch 46: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0884 - tp: 46548.0000 - fp: 6153.0000 - tn: 158930.0000 - fn: 1369.0000 - accuracy: 0.9647 - precision: 0.8832 - recall: 0.9714 - prc: 0.9794 - val_loss: 0.3242 - val_tp: 3061.0000 - val_fp: 3331.0000 - val_tn: 29570.0000 - val_fn: 638.0000 - val_accuracy: 0.8916 - val_precision: 0.4789 - val_recall: 0.8275 - val_prc: 0.6647
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0636 - tp: 47043.0000 - fp: 4570.0000 - tn: 160513.0000 - fn: 874.0000 - accuracy: 0.9744 - precision: 0.9115 - recall: 0.9818 - prc: 0.9887
# Epoch 47: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0636 - tp: 47043.0000 - fp: 4570.0000 - tn: 160513.0000 - fn: 874.0000 - accuracy: 0.9744 - precision: 0.9115 - recall: 0.9818 - prc: 0.9887 - val_loss: 0.2730 - val_tp: 3174.0000 - val_fp: 2918.0000 - val_tn: 29983.0000 - val_fn: 525.0000 - val_accuracy: 0.9059 - val_precision: 0.5210 - val_recall: 0.8581 - val_prc: 0.7270
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0675 - tp: 46907.0000 - fp: 4759.0000 - tn: 160324.0000 - fn: 1010.0000 - accuracy: 0.9729 - precision: 0.9079 - recall: 0.9789 - prc: 0.9877
# Epoch 48: val_loss did not improve from 0.18224
# 12/12 [==============================] - 36s 3s/step - loss: 0.0675 - tp: 46907.0000 - fp: 4759.0000 - tn: 160324.0000 - fn: 1010.0000 - accuracy: 0.9729 - precision: 0.9079 - recall: 0.9789 - prc: 0.9877 - val_loss: 0.2081 - val_tp: 2959.0000 - val_fp: 1830.0000 - val_tn: 31071.0000 - val_fn: 740.0000 - val_accuracy: 0.9298 - val_precision: 0.6179 - val_recall: 0.7999 - val_prc: 0.7623
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0584 - tp: 46944.0000 - fp: 3738.0000 - tn: 161345.0000 - fn: 973.0000 - accuracy: 0.9779 - precision: 0.9262 - recall: 0.9797 - prc: 0.9914
# Epoch 49: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0584 - tp: 46944.0000 - fp: 3738.0000 - tn: 161345.0000 - fn: 973.0000 - accuracy: 0.9779 - precision: 0.9262 - recall: 0.9797 - prc: 0.9914 - val_loss: 0.2102 - val_tp: 3053.0000 - val_fp: 1974.0000 - val_tn: 30927.0000 - val_fn: 646.0000 - val_accuracy: 0.9284 - val_precision: 0.6073 - val_recall: 0.8254 - val_prc: 0.7706
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0523 - tp: 47164.0000 - fp: 3546.0000 - tn: 161537.0000 - fn: 753.0000 - accuracy: 0.9798 - precision: 0.9301 - recall: 0.9843 - prc: 0.9928
# Epoch 50: val_loss did not improve from 0.18224
# 12/12 [==============================] - 35s 3s/step - loss: 0.0523 - tp: 47164.0000 - fp: 3546.0000 - tn: 161537.0000 - fn: 753.0000 - accuracy: 0.9798 - precision: 0.9301 - recall: 0.9843 - prc: 0.9928 - val_loss: 0.2044 - val_tp: 2995.0000 - val_fp: 1930.0000 - val_tn: 30971.0000 - val_fn: 704.0000 - val_accuracy: 0.9280 - val_precision: 0.6081 - val_recall: 0.8097 - val_prc: 0.7736
# Results:
# 	Loss: 0.1822417676448822
# 	TruePositives: 2668.0
# 	FalsePositives: 1382.0
# 	TrueNegatives: 31519.0
# 	FalseNegatives: 1031.0
# 	Accuracy: 0.9340710639953613
# 	Precision: 0.658765435218811
# 	Recall: 0.7212759852409363
# 	PRC: 0.7442824840545654
# 12/12 [==============================] - 16s 1s/step
# 2/2 [==============================] - 4s 3s/step

# %% [markdown]
# ## Evaluate model
#
# On the following section we will evaluate the model on the validation set.

# %%
from evaluation_utils import *
import keras

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load validation data
path = '../data/processed/Dataset/'
val_data = load_dataset(path, 'resnet')
print('Validation videos: ', val_data.keys())

# Per each video, generate sequences
val_seq = {}
for i in list(val_data.keys()):
    X, Y = generate_sequences(val_data[i], 600)
    val_seq[i] = [X, Y]

behaviours = ['Grooming', 'Rearing']

# We will load the models
with keras.utils.custom_object_scope({'TCN': TCN}):
    
    if 'Grooming' in behaviours:
        model_grooming = keras.models.load_model('tcn12_aumented_grooming.h5', compile=True)
    if 'Rearing' in behaviours:
        model_rearing = keras.models.load_model('tcn12_aumented_rearing.h5', compile=True)

# Initialzie dataframes to save metrics
df_g = pd.DataFrame(columns=['Accuracy','Precision','Recall','PRC'], index=list(val_data.keys()))
df_r = pd.DataFrame(columns=['Accuracy','Precision','Recall','PRC'], index=list(val_data.keys()))
# Out:
# Validation videos:  dict_keys(['1', 'Animal62418', 'HD_ChR2_480A'])

# %%
df_g
# Out:
#               Accuracy Precision    Recall       PRC
# 1             0.995238  0.942308     0.875  0.955281
# Animal62418   0.962273   0.67101  0.581921  0.682609
# HD_ChR2_480A  0.940833  0.832105  0.936611  0.905517

# %%
df_r
# Out:
#               Accuracy Precision    Recall       PRC
# 1             0.989524  0.894737  0.459459  0.743032
# Animal62418   0.906061  0.689899  0.685743  0.779284
# HD_ChR2_480A  0.901528  0.701802  0.673293  0.754178

# %% [markdown]
# ### Results video 1.mp4

# %%
X, Y = val_seq['1']

# Add metrics to DataFrame
df_g.loc['1'] = model_grooming.evaluate(X,Y[:,:,0])[-4:]
df_r.loc['1'] = model_rearing.evaluate(X,Y[:,:,1])[-4:]

pred_g = np.ndarray.flatten(model_grooming.predict(X)[:,:,0])
label_g = np.ndarray.flatten(Y[:,:,0])

pred_r = np.ndarray.flatten(model_rearing.predict(X)[:,:,0])
label_r = np.ndarray.flatten(Y[:,:,1])
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.0207 - tp: 98.0000 - fp: 6.0000 - tn: 4082.0000 - fn: 14.0000 - accuracy: 0.9952 - precision: 0.9423 - recall: 0.8750 - prc: 0.9553
# 1/1 [==============================] - 4s 4s/step - loss: 0.0295 - tp: 34.0000 - fp: 4.0000 - tn: 4122.0000 - fn: 40.0000 - accuracy: 0.9895 - precision: 0.8947 - recall: 0.4595 - prc: 0.7430
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step

# %%
print('We will start by plotting the labels and actual predictions along the video frames.')
for b in behaviours:
    if b == 'Grooming':
        plot_behaviours(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_behaviours(label_r, pred_r, b)

print('We will compute the PRC curve to choose the best threshold.')
for b in behaviours:
    if b == 'Grooming':
        plot_PRC_Curve(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_PRC_Curve(label_r, pred_r, b)

print('Lastly we will plot the confussion matrix for each behaviour')
for b in behaviours:
    if b == 'Grooming':
        plot_confussionmatrix(label_g, pred_g, b, threshold=0.5)
    elif b == 'Rearing':
        plot_confussionmatrix(label_r, pred_r, b, threshold=0.5)
# Out:
# We will start by plotting the labels and actual predictions along the video frames.
# We will compute the PRC curve to choose the best threshold.
# Lastly we will plot the confussion matrix for each behaviour

# %% [markdown]
# ### Results video Animal62418.mp4

# %%
X, Y = val_seq['Animal62418']

# Add metrics to DataFrame
df_g.loc['Animal62418'] = model_grooming.evaluate(X,Y[:,:,0])[-4:]
df_r.loc['Animal62418'] = model_rearing.evaluate(X,Y[:,:,1])[-4:]

pred_g = np.ndarray.flatten(model_grooming.predict(X)[:,:,0])
label_g = np.ndarray.flatten(Y[:,:,0])

pred_r = np.ndarray.flatten(model_rearing.predict(X)[:,:,0])
label_r = np.ndarray.flatten(Y[:,:,1])
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.1418 - tp: 206.0000 - fp: 101.0000 - tn: 6145.0000 - fn: 148.0000 - accuracy: 0.9623 - precision: 0.6710 - recall: 0.5819 - prc: 0.6826
# 1/1 [==============================] - 2s 2s/step - loss: 0.2290 - tp: 683.0000 - fp: 307.0000 - tn: 5297.0000 - fn: 313.0000 - accuracy: 0.9061 - precision: 0.6899 - recall: 0.6857 - prc: 0.7793
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step

# %%
print('We will start by plotting the labels and actual predictions along the video frames.')
for b in behaviours:
    if b == 'Grooming':
        plot_behaviours(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_behaviours(label_r, pred_r, b)

print('We will compute the PRC curve to choose the best threshold.')
for b in behaviours:
    if b == 'Grooming':
        plot_PRC_Curve(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_PRC_Curve(label_r, pred_r, b)

print('Lastly we will plot the confussion matrix for each behaviour')
for b in behaviours:
    if b == 'Grooming':
        plot_confussionmatrix(label_g, pred_g, b, threshold=0.5)
    elif b == 'Rearing':
        plot_confussionmatrix(label_r, pred_r, b, threshold=0.5)
# Out:
# We will start by plotting the labels and actual predictions along the video frames.
# We will compute the PRC curve to choose the best threshold.
# Lastly we will plot the confussion matrix for each behaviour

# %% [markdown]
# ### Results video HD_ChR2_480A.mp4

# %%
X, Y = val_seq['HD_ChR2_480A']

# Add metrics to DataFrame
df_g.loc['HD_ChR2_480A'] = model_grooming.evaluate(X,Y[:,:,0])[-4:]
df_r.loc['HD_ChR2_480A'] = model_rearing.evaluate(X,Y[:,:,1])[-4:]

pred_g = np.ndarray.flatten(model_grooming.predict(X)[:,:,0])
label_g = np.ndarray.flatten(Y[:,:,0])

pred_r = np.ndarray.flatten(model_rearing.predict(X)[:,:,0])
label_r = np.ndarray.flatten(Y[:,:,1])
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.1674 - tp: 1581.0000 - fp: 319.0000 - tn: 5193.0000 - fn: 107.0000 - accuracy: 0.9408 - precision: 0.8321 - recall: 0.9366 - prc: 0.9055
# 1/1 [==============================] - 2s 2s/step - loss: 0.2485 - tp: 779.0000 - fp: 331.0000 - tn: 5712.0000 - fn: 378.0000 - accuracy: 0.9015 - precision: 0.7018 - recall: 0.6733 - prc: 0.7542
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step

# %%
print('We will start by plotting the labels and actual predictions along the video frames.')
for b in behaviours:
    if b == 'Grooming':
        plot_behaviours(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_behaviours(label_r, pred_r, b)

print('We will compute the PRC curve to choose the best threshold.')
for b in behaviours:
    if b == 'Grooming':
        plot_PRC_Curve(label_g, pred_g, b)
    elif b == 'Rearing':
        plot_PRC_Curve(label_r, pred_r, b)

print('Lastly we will plot the confussion matrix for each behaviour')
for b in behaviours:
    if b == 'Grooming':
        plot_confussionmatrix(label_g, pred_g, b, threshold=0.5)
    elif b == 'Rearing':
        plot_confussionmatrix(label_r, pred_r, b, threshold=0.5)
# Out:
# We will start by plotting the labels and actual predictions along the video frames.
# We will compute the PRC curve to choose the best threshold.
# Lastly we will plot the confussion matrix for each behaviour
